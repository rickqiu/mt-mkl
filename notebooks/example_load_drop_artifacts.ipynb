# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
path = "/home/vanessa/DATA_SEEG/IDlabels/"

# %%
ylist = os.listdir(path)
for yfile in ylist:
    df = pd.read_csv(path + yfile)
    print(df.head())
# Out:
#    B01-B02  1
# 0  B02-B03  1
# 1  B03-B04  1
# 2  B04-B05  1
# 3  B09-B10  1
# 4  B10-B11  1
#    B02-B03  1
# 0  B03-B04 -1
# 1  B04-B05 -1
# 2  B05-B06 -1
# 3  B06-B07 -1
# 4  B07-B08 -1
#    E'01-E'02  -1
# 0  E'02-E'03  -1
# 1  E'03-E'04  -1
# 2  E'06-E'07   1
# 3  E'07-E'08   1
# 4  E'08-E'09   1
#    J01-J02  1
# 0  J02-J03  1
# 1  J03-J04  1
# 2  J08-J09 -1
# 3  J09-J10 -1
# 4  J10-J11 -1
#    D01-D02  -1
# 0  D02-D03  -1
# 1  D03-D04  -1
# 2  D04-D05  -1
# 3  D05-D06  -1
# 4  D06-D07  -1
#    B'01-B'02  1
# 0  B'02-B'03  1
# 1  B'03-B'04  1
# 2  B'04-B'05  1
# 3  B'05-B'06  1
# 4  B'06-B'07 -1
#    B01-B02  1
# 0  B02-B03  1
# 1  B03-B04  1
# 2  B04-B05  1
# 3  B10-B11 -1
# 4  B11-B12 -1
#    A'01-A'02  -1
# 0  A'02-A'03  -1
# 1  A'03-A'04  -1
# 2  A'07-A'08  -1
# 3  A'08-A'09  -1
# 4  A'09-A'10  -1
#    C'01-C'02  -1
# 0  C'02-C'03  -1
# 1  C'03-C'04  -1
# 2  C'04-C'05  -1
# 3  C'05-C'06  -1
# 4  C'06-C'07  -1
#    B01-B02  1
# 0  B02-B03  1
# 1  B03-B04  1
# 2  B04-B05  1
# ...

# %%
pathkernel = "/home/vanessa/DATA_SEEG/PKL_FILE/"
